# %% [markdown]
# <a href="https://colab.research.google.com/github/KESHAVNATH8/Machine-Learning-Project/blob/main/PalmerDetection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Install Dependencies
#
# _(Remember to choose GPU in Runtime if not already selected. Runtime --> Change Runtime Type --> Hardware accelerator --> GPU)_

# %%
# clone YOLOv5 repository
# !git clone https://github.com/ultralytics/yolov5  # clone repo
# %cd yolov5
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 16522, done.
# remote: Counting objects: 100% (120/120), done.
# remote: Compressing objects: 100% (104/104), done.
# remote: Total 16522 (delta 48), reused 51 (delta 16), pack-reused 16402
# Receiving objects: 100% (16522/16522), 15.19 MiB | 7.54 MiB/s, done.
# Resolving deltas: 100% (11308/11308), done.
# /content/yolov5

# %%
# install dependencies as necessary
# !pip install -qr requirements.txt  # install dependencies (ignore errors)
import torch

from IPython.display import Image, clear_output  # to display images
from utils.downloads import attempt_download  # to download models/datasets

# clear_output()
print('Setup complete. Using torch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 195.4/195.4 kB 3.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 723.1/723.1 kB 31.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 6.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 25.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 61.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 90.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 2.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 3.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 8.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 13.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 8.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 6.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 7.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 13.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 76.8 MB/s eta 0:00:00
# Setup complete. Using torch 2.2.1+cu121 _CudaDeviceProperties(name='Tesla T4', major=7, minor=5, total_memory=15102MB, multi_processor_count=40)

# %% [markdown]
# ## Step 6: Download a Dataset
#
# Add your Roboflow API key below to download the default money counting dataset. Alternatively, use the code provided by the Roboflow dashboard in the above step to load a custom dataset.

# %%
# !pip install -q roboflow
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.9/71.9 kB 2.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.3/158.3 kB 13.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 24.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 5.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 MB 9.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 7.7 MB/s eta 0:00:00

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="5yGq3sGJYVMBFoNPmLlJ")
project = rf.workspace("face-recognition-zqouj").project("palmernotation")
version = project.version(2)
dataset = version.download("yolov5")
# Out:
# Requirement already satisfied: roboflow in /usr/local/lib/python3.10/dist-packages (1.1.25)
# Requirement already satisfied: certifi==2023.7.22 in /usr/local/lib/python3.10/dist-packages (from roboflow) (2023.7.22)
# Requirement already satisfied: chardet==4.0.0 in /usr/local/lib/python3.10/dist-packages (from roboflow) (4.0.0)
# Requirement already satisfied: cycler==0.10.0 in /usr/local/lib/python3.10/dist-packages (from roboflow) (0.10.0)
# Requirement already satisfied: idna==2.10 in /usr/local/lib/python3.10/dist-packages (from roboflow) (2.10)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.4.5)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from roboflow) (3.7.1)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.25.2)
# Requirement already satisfied: opencv-python-headless==4.8.0.74 in /usr/local/lib/python3.10/dist-packages (from roboflow) (4.8.0.74)
# Requirement already satisfied: Pillow>=7.1.2 in /usr/local/lib/python3.10/dist-packages (from roboflow) (9.4.0)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from roboflow) (2.8.2)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.0.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from roboflow) (2.31.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.16.0)
# Requirement already satisfied: urllib3>=1.26.6 in /usr/local/lib/python3.10/dist-packages (from roboflow) (2.0.7)
# Requirement already satisfied: tqdm>=4.41.0 in /usr/local/lib/python3.10/dist-packages (from roboflow) (4.66.2)
# Requirement already satisfied: PyYAML>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from roboflow) (6.0.1)
# Requirement already satisfied: requests-toolbelt in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.0.0)
# Requirement already satisfied: python-magic in /usr/local/lib/python3.10/dist-packages (from roboflow) (0.4.27)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (1.2.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (4.50.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (24.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (3.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->roboflow) (3.3.2)
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in PalmerNotation-2 to yolov5pytorch:: 100%|██████████| 55928/55928 [00:04<00:00, 13571.84it/s]
# Extracting Dataset Version Zip to PalmerNotation-2 in yolov5pytorch:: 100%|██████████| 3266/3266 [00:00<00:00, 6003.25it/s]

# %%
# %pwd
# Out:
# '/content/yolov5'

# %%
dataset.location
# Out:
# '/content/yolov5/PalmerNotation-2'

# %%
# %cd /content/yolov5
# Out:
# /content/yolov5

# %%
dataset.location
# Out:
# '/content/yolov5/PalmerNotation-2'

# %%
# this is the YAML file Roboflow wrote for us that we're loading into this notebook with our data
# %cat {dataset.location}/data.yaml
# Out:
# names:
# - palmer
# nc: 1
# roboflow:
#   license: CC BY 4.0
#   project: palmernotation
#   url: https://universe.roboflow.com/face-recognition-zqouj/palmernotation/dataset/2
#   version: 2
#   workspace: face-recognition-zqouj
# test: ../test/images
# train: PalmerNotation-2/train/images
# val: PalmerNotation-2/valid/images

# %% [markdown]
# # Define Model Configuration and Architecture
#
# We will write a yaml script that defines the parameters for our model like the number of classes, anchors, and each layer.
#
# You do not need to edit these cells, but you may.

# %%
# define number of classes based on YAML
import yaml
with open(dataset.location + "/data.yaml", 'r') as stream:
    num_classes = str(yaml.safe_load(stream)['nc'])

# %%
num_classes
# Out:
# '1'

# %%
#this is the model configuration we will use for our tutorial
# %cat /content/yolov5/models/yolov5s.yaml
# Out:
# # YOLOv5 🚀 by Ultralytics, AGPL-3.0 license
#
# # Parameters
# nc: 80 # number of classes
# depth_multiple: 0.33 # model depth multiple
# width_multiple: 0.50 # layer channel multiple
# anchors:
#   - [10, 13, 16, 30, 33, 23] # P3/8
#   - [30, 61, 62, 45, 59, 119] # P4/16
#   - [116, 90, 156, 198, 373, 326] # P5/32
#
# # YOLOv5 v6.0 backbone
# backbone:
#   # [from, number, module, args]
#   [
#     [-1, 1, Conv, [64, 6, 2, 2]], # 0-P1/2
#     [-1, 1, Conv, [128, 3, 2]], # 1-P2/4
#     [-1, 3, C3, [128]],
#     [-1, 1, Conv, [256, 3, 2]], # 3-P3/8
#     [-1, 6, C3, [256]],
#     [-1, 1, Conv, [512, 3, 2]], # 5-P4/16
#     [-1, 9, C3, [512]],
#     [-1, 1, Conv, [1024, 3, 2]], # 7-P5/32
#     [-1, 3, C3, [1024]],
#     [-1, 1, SPPF, [1024, 5]], # 9
#   ]
#
# # YOLOv5 v6.0 head
# head: [
#     [-1, 1, Conv, [512, 1, 1]],
#     [-1, 1, nn.Upsample, [None, 2, "nearest"]],
#     [[-1, 6], 1, Concat, [1]], # cat backbone P4
#     [-1, 3, C3, [512, False]], # 13
#
#     [-1, 1, Conv, [256, 1, 1]],
#     [-1, 1, nn.Upsample, [None, 2, "nearest"]],
#     [[-1, 4], 1, Concat, [1]], # cat backbone P3
#     [-1, 3, C3, [256, False]], # 17 (P3/8-small)
#
#     [-1, 1, Conv, [256, 3, 2]],
#     [[-1, 14], 1, Concat, [1]], # cat head P4
#     [-1, 3, C3, [512, False]], # 20 (P4/16-medium)
#
#     [-1, 1, Conv, [512, 3, 2]],
#     [[-1, 10], 1, Concat, [1]], # cat head P5
#     [-1, 3, C3, [1024, False]], # 23 (P5/32-large)
#
#     [[17, 20, 23], 1, Detect, [nc, anchors]], # Detect(P3, P4, P5)
#   ]

# %%
#customize iPython writefile so we can write variables
from IPython.core.magic import register_line_cell_magic

@register_line_cell_magic
def writetemplate(line, cell):
    with open(line, 'w') as f:
        f.write(cell.format(**globals()))

# %%
# %%writetemplate /content/yolov5/models/custom_yolov5s.yaml
#
# # parameters
# nc: {num_classes}  # number of classes
# depth_multiple: 0.33  # model depth multiple
# width_multiple: 0.50  # layer channel multiple
#
# # anchors
# anchors:
#   - [10,13, 16,30, 33,23]  # P3/8
#   - [30,61, 62,45, 59,119]  # P4/16
#   - [116,90, 156,198, 373,326]  # P5/32
#
# # YOLOv5 backbone
# backbone:
#   # [from, number, module, args]
#   [[-1, 1, Focus, [64, 3]],  # 0-P1/2
#    [-1, 1, Conv, [128, 3, 2]],  # 1-P2/4
#    [-1, 3, BottleneckCSP, [128]],
#    [-1, 1, Conv, [256, 3, 2]],  # 3-P3/8
#    [-1, 9, BottleneckCSP, [256]],
#    [-1, 1, Conv, [512, 3, 2]],  # 5-P4/16
#    [-1, 9, BottleneckCSP, [512]],
#    [-1, 1, Conv, [1024, 3, 2]],  # 7-P5/32
#    [-1, 1, SPP, [1024, [5, 9, 13]]],
#    [-1, 3, BottleneckCSP, [1024, False]],  # 9
#   ]
#
# # YOLOv5 head
# head:
#   [[-1, 1, Conv, [512, 1, 1]],
#    [-1, 1, nn.Upsample, [None, 2, 'nearest']],
#    [[-1, 6], 1, Concat, [1]],  # cat backbone P4
#    [-1, 3, BottleneckCSP, [512, False]],  # 13
#
#    [-1, 1, Conv, [256, 1, 1]],
#    [-1, 1, nn.Upsample, [None, 2, 'nearest']],
#    [[-1, 4], 1, Concat, [1]],  # cat backbone P3
#    [-1, 3, BottleneckCSP, [256, False]],  # 17 (P3/8-small)
#
#    [-1, 1, Conv, [256, 3, 2]],
#    [[-1, 14], 1, Concat, [1]],  # cat head P4
#    [-1, 3, BottleneckCSP, [512, False]],  # 20 (P4/16-medium)
#
#    [-1, 1, Conv, [512, 3, 2]],
#    [[-1, 10], 1, Concat, [1]],  # cat head P5
#    [-1, 3, BottleneckCSP, [1024, False]],  # 23 (P5/32-large)
#
#    [[17, 20, 23], 1, Detect, [nc, anchors]],  # Detect(P3, P4, P5)
#   ]

# %% [markdown]
# # Train Custom YOLOv5 Detector
#
# ### Next, we'll fire off training!
#
#
# Here, we are able to pass a number of arguments:
# - **img:** define input image size
# - **batch:** determine batch size
# - **epochs:** define the number of training epochs. (Note: often, 3000+ are common here!)
# - **data:** set the path to our yaml file
# - **cfg:** specify our model configuration
# - **weights:** specify a custom path to weights. (Note: you can download weights from the Ultralytics Google Drive [folder](https://drive.google.com/open?id=1Drs_Aiu7xx6S-ix95f9kNsA6ueKRpN2J))
# - **name:** result names
# - **nosave:** only save the final checkpoint
# - **cache:** cache images for faster training

# %%
# train yolov5s on custom data for 200 epochs
# time its performance
# %%time
# %cd /content/yolov5/
# !python train.py --img 416 --batch 16 --epochs 50 --data {dataset.location}/data.yaml --cfg ./models/custom_yolov5s.yaml --weights 'yolov5s.pt' --name yolov5s_results  --cache
# Out:
# /content/yolov5
# 2024-03-25 04:59:26.603254: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-25 04:59:26.603370: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-25 04:59:26.737064: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# train: weights=yolov5s.pt, cfg=./models/custom_yolov5s.yaml, data=/content/yolov5/PalmerNotation-2/data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=50, batch_size=16, imgsz=416, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, evolve_population=data/hyps, resume_evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=yolov5s_results, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest, ndjson_console=False, ndjson_file=False
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-295-gac6c4383 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# Comet: run 'pip install comet_ml' to automatically track and visualize YOLOv5 🚀 runs in Comet
# TensorBoard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# Downloading https://ultralytics.com/assets/Arial.ttf to /root/.config/Ultralytics/Arial.ttf...
# 100% 755k/755k [00:00<00:00, 153MB/s]
# Downloading https://github.com/ultralytics/yolov5/releases/download/v7.0/yolov5s.pt to yolov5s.pt...
# 100% 14.1M/14.1M [00:00<00:00, 315MB/s]
#
#
#                  from  n    params  module                                  arguments
#   0                -1  1      3520  models.common.Focus                     [3, 32, 3]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   2                -1  1     19904  models.common.BottleneckCSP             [64, 64, 1]
#   3                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   4                -1  3    161152  models.common.BottleneckCSP             [128, 128, 3]
#   5                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   6                -1  3    641792  models.common.BottleneckCSP             [256, 256, 3]
#   7                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   8                -1  1    656896  models.common.SPP                       [512, 512, [5, 9, 13]]
#   9                -1  1   1248768  models.common.BottleneckCSP             [512, 512, 1, False]
#  10                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  1    378624  models.common.BottleneckCSP             [512, 256, 1, False]
#  14                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  1     95104  models.common.BottleneckCSP             [256, 128, 1, False]
#  18                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  1    313088  models.common.BottleneckCSP             [256, 256, 1, False]
#  21                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  1   1248768  models.common.BottleneckCSP             [512, 512, 1, False]
#  24      [17, 20, 23]  1     16182  models.yolo.Detect                      [1, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [128, 256, 512]]
# custom_YOLOv5s summary: 233 layers, 7255094 parameters, 7255094 gradients
#
# Transferred 223/369 items from yolov5s.pt
# AMP: checks passed ✅
# optimizer: SGD(lr=0.01) with parameter groups 59 weight(decay=0.0), 70 weight(decay=0.0005), 62 bias
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# train: Scanning /content/yolov5/PalmerNotation-2/train/labels... 1139 images, 9 backgrounds, 0 corrupt: 100% 1139/1139 [00:00<00:00, 1742.64it/s]
# train: New cache created: /content/yolov5/PalmerNotation-2/train/labels.cache
# train: Caching images (0.6GB ram): 100% 1139/1139 [00:06<00:00, 178.55it/s]
# val: Scanning /content/yolov5/PalmerNotation-2/valid/labels... 325 images, 4 backgrounds, 0 corrupt: 100% 325/325 [00:00<00:00, 636.84it/s]
# val: New cache created: /content/yolov5/PalmerNotation-2/valid/labels.cache
# val: Caching images (0.2GB ram): 100% 325/325 [00:03<00:00, 102.23it/s]
#
# AutoAnchor: 4.72 anchors/target, 0.997 Best Possible Recall (BPR). Current anchors are a good fit to dataset ✅
# Plotting labels to runs/train/yolov5s_results/labels.jpg...
# Image sizes 416 train, 416 val
# Using 2 dataloader workers
# Logging results to runs/train/yolov5s_results
# Starting training for 50 epochs...
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        0/49      1.74G     0.1073    0.03563          0         20        416: 100% 72/72 [00:17<00:00,  4.06it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 11/11 [00:08<00:00,  1.37it/s]
#                    all        325       1304   0.000421     0.0314   0.000241   5.91e-05
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        1/49      2.04G     0.1001     0.0371          0         37        416: 100% 72/72 [00:11<00:00,  6.12it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 11/11 [00:04<00:00,  2.26it/s]
#                    all        325       1304    0.00146      0.109      0.001   0.000219
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        2/49      2.04G    0.09139    0.03699          0         18        416: 100% 72/72 [00:11<00:00,  6.44it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 11/11 [00:03<00:00,  3.20it/s]
#                    all        325       1304      0.138      0.193     0.0686     0.0184
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        3/49      2.04G    0.08024    0.03487          0         16        416: 100% 72/72 [00:11<00:00,  6.48it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 11/11 [00:04<00:00,  2.28it/s]
#                    all        325       1304      0.176      0.237      0.114     0.0284
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        4/49      2.04G    0.07288     0.0319          0         29        416: 100% 72/72 [00:10<00:00,  7.00it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 11/11 [00:03<00:00,  2.92it/s]
#                    all        325       1304       0.64      0.606       0.62       0.22
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        5/49      2.04G     0.0663    0.03037          0         20        416: 100% 72/72 [00:11<00:00,  6.53it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 11/11 [00:04<00:00,  2.70it/s]
#                    all        325       1304      0.583      0.548      0.538      0.188
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        6/49      2.04G    0.06294    0.02803          0         10        416: 100% 72/72 [00:11<00:00,  6.50it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 11/11 [00:03<00:00,  3.65it/s]
#                    all        325       1304      0.813      0.629      0.713      0.282
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        7/49      2.04G    0.05947    0.02686          0         14        416: 100% 72/72 [00:11<00:00,  6.49it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 11/11 [00:02<00:00,  3.72it/s]
#                    all        325       1304      0.868      0.846      0.889      0.397
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        8/49      2.04G    0.05685    0.02569          0         21        416: 100% 72/72 [00:11<00:00,  6.48it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 11/11 [00:03<00:00,  3.59it/s]
#                    all        325       1304      0.298      0.227      0.188     0.0428
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        9/49      2.04G     0.0551    0.02515          0         15        416: 100% 72/72 [00:10<00:00,  7.10it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 11/11 [00:03<00:00,  3.29it/s]
#                    all        325       1304      0.875      0.845      0.881      0.394
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       10/49      2.04G    0.05433    0.02361          0          8        416: 100% 72/72 [00:11<00:00,  6.53it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 11/11 [00:02<00:00,  4.08it/s]
#                    all        325       1304      0.832      0.736      0.806      0.333
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       11/49      2.04G    0.05299    0.02442          0         29        416: 100% 72/72 [00:11<00:00,  6.48it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 11/11 [00:02<00:00,  4.12it/s]
#                    all        325       1304      0.423      0.346      0.299     0.0954
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       12/49      2.04G    0.05271    0.02321          0         20        416: 100% 72/72 [00:11<00:00,  6.42it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 11/11 [00:02<00:00,  4.19it/s]
#                    all        325       1304      0.848      0.833      0.874      0.397
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       13/49      2.04G     0.0504    0.02221          0         15        416: 100% 72/72 [00:10<00:00,  6.55it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 11/11 [00:02<00:00,  4.17it/s]
#                    all        325       1304      0.918      0.898      0.919      0.428
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       14/49      2.04G    0.05005    0.02303          0         26        416: 100% 72/72 [00:11<00:00,  6.48it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 11/11 [00:02<00:00,  4.02it/s]
#                    all        325       1304      0.609      0.506      0.501      0.155
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       15/49      2.04G    0.04893    0.02296          0         19        416: 100% 72/72 [00:11<00:00,  6.49it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 11/11 [00:02<00:00,  3.85it/s]
#                    all        325       1304      0.543      0.482      0.447      0.147
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       16/49      2.04G     0.0483    0.02216          0         21        416: 100% 72/72 [00:10<00:00,  6.62it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 11/11 [00:03<00:00,  3.32it/s]
#                    all        325       1304      0.922      0.921      0.926      0.463
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       17/49      2.04G     0.0475    0.02149          0          7        416: 100% 72/72 [00:10<00:00,  6.70it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 11/11 [00:02<00:00,  3.82it/s]
#                    all        325       1304      0.834      0.803      0.829      0.348
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       18/49      2.04G    0.04816    0.02194          0         12        416: 100% 72/72 [00:11<00:00,  6.44it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 11/11 [00:02<00:00,  4.15it/s]
#                    all        325       1304      0.901      0.875      0.894      0.417
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       19/49      2.04G    0.04763    0.02192          0         22        416: 100% 72/72 [00:11<00:00,  6.43it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 11/11 [00:02<00:00,  4.19it/s]
#                    all        325       1304      0.925      0.913      0.924      0.462
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       20/49      2.04G    0.04615    0.02113          0         14        416: 100% 72/72 [00:11<00:00,  6.44it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 11/11 [00:02<00:00,  4.44it/s]
#                    all        325       1304      0.664      0.396      0.428      0.151
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       21/49      2.04G    0.04569    0.02012          0         18        416: 100% 72/72 [00:11<00:00,  6.41it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 11/11 [00:02<00:00,  4.11it/s]
#                    all        325       1304      0.929      0.934      0.934      0.478
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       22/49      2.04G    0.04511    0.02149          0         21        416: 100% 72/72 [00:11<00:00,  6.41it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 11/11 [00:02<00:00,  3.99it/s]
#                    all        325       1304      0.921      0.931      0.927      0.456
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       23/49      2.04G    0.04513    0.02048          0         10        416: 100% 72/72 [00:10<00:00,  6.74it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 11/11 [00:03<00:00,  3.36it/s]
#                    all        325       1304      0.919       0.93      0.932      0.469
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       24/49      2.04G    0.04532    0.02078          0         16        416: 100% 72/72 [00:10<00:00,  6.77it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 11/11 [00:03<00:00,  3.63it/s]
#                    all        325       1304      0.925      0.946       0.93      0.477
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       25/49      2.04G    0.04508    0.02077          0         11        416: 100% 72/72 [00:11<00:00,  6.48it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 11/11 [00:02<00:00,  4.21it/s]
#                    all        325       1304      0.763       0.68      0.713      0.264
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       26/49      2.04G    0.04429    0.02056          0         14        416: 100% 72/72 [00:11<00:00,  6.40it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 11/11 [00:02<00:00,  4.17it/s]
#                    all        325       1304      0.933      0.936       0.93      0.479
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       27/49      2.04G    0.04356    0.02065          0         16        416: 100% 72/72 [00:11<00:00,  6.37it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 11/11 [00:02<00:00,  4.12it/s]
#                    all        325       1304      0.931      0.937      0.936      0.474
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       28/49      2.04G    0.04339    0.02052          0          8        416: 100% 72/72 [00:11<00:00,  6.49it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 11/11 [00:02<00:00,  4.12it/s]
#                    all        325       1304      0.866      0.805      0.853      0.334
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       29/49      2.04G    0.04271    0.02018          0         11        416: 100% 72/72 [00:11<00:00,  6.47it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 11/11 [00:02<00:00,  4.18it/s]
#                    all        325       1304      0.924      0.942      0.931      0.474
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       30/49      2.04G    0.04297    0.02005          0          9        416: 100% 72/72 [00:10<00:00,  6.64it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 11/11 [00:03<00:00,  3.46it/s]
#                    all        325       1304      0.933      0.944      0.937      0.497
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       31/49      2.04G    0.04296    0.02007          0         25        416: 100% 72/72 [00:10<00:00,  6.85it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 11/11 [00:03<00:00,  3.61it/s]
#                    all        325       1304      0.937      0.939      0.933      0.473
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       32/49      2.04G    0.04237    0.01986          0         19        416: 100% 72/72 [00:11<00:00,  6.47it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 11/11 [00:02<00:00,  4.18it/s]
#                    all        325       1304      0.907      0.916      0.914      0.454
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       33/49      2.04G    0.04236    0.01982          0         12        416: 100% 72/72 [00:11<00:00,  6.37it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 11/11 [00:02<00:00,  4.16it/s]
#                    all        325       1304       0.93       0.96      0.936      0.503
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       34/49      2.04G    0.04132    0.01955          0         16        416: 100% 72/72 [00:11<00:00,  6.42it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 11/11 [00:02<00:00,  4.19it/s]
#                    all        325       1304      0.924       0.94      0.933      0.477
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       35/49      2.04G    0.04045    0.01869          0          3        416: 100% 72/72 [00:11<00:00,  6.42it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 11/11 [00:02<00:00,  4.15it/s]
#                    all        325       1304      0.933      0.935      0.932      0.472
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       36/49      2.04G    0.04123    0.01878          0          5        416: 100% 72/72 [00:11<00:00,  6.45it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 11/11 [00:02<00:00,  4.11it/s]
#                    all        325       1304       0.94      0.945      0.933      0.492
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       37/49      2.04G    0.04211    0.02076          0         21        416: 100% 72/72 [00:11<00:00,  6.36it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 11/11 [00:03<00:00,  3.61it/s]
#                    all        325       1304      0.904      0.925      0.921      0.465
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       38/49      2.04G    0.04118    0.01964          0         10        416: 100% 72/72 [00:10<00:00,  7.03it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 11/11 [00:03<00:00,  3.42it/s]
#                    all        325       1304      0.898      0.908      0.914      0.447
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       39/49      2.04G    0.04088    0.01884          0         15        416: 100% 72/72 [00:11<00:00,  6.47it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 11/11 [00:02<00:00,  4.17it/s]
#                    all        325       1304      0.861      0.815      0.856      0.387
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       40/49      2.04G    0.04151    0.02003          0         23        416: 100% 72/72 [00:11<00:00,  6.46it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 11/11 [00:02<00:00,  4.01it/s]
#                    all        325       1304      0.935      0.956      0.941      0.501
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       41/49      2.04G    0.04106    0.01936          0         15        416: 100% 72/72 [00:11<00:00,  6.39it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 11/11 [00:02<00:00,  4.14it/s]
#                    all        325       1304      0.932      0.947      0.938      0.483
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       42/49      2.04G    0.04043    0.01887          0         11        416: 100% 72/72 [00:11<00:00,  6.43it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 11/11 [00:02<00:00,  4.18it/s]
#                    all        325       1304      0.911      0.945      0.929       0.48
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       43/49      2.04G     0.0407    0.01952          0         12        416: 100% 72/72 [00:11<00:00,  6.47it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 11/11 [00:02<00:00,  4.17it/s]
#                    all        325       1304      0.924      0.944      0.932      0.468
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       44/49      2.04G    0.04082    0.01918          0         16        416: 100% 72/72 [00:11<00:00,  6.41it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 11/11 [00:02<00:00,  4.12it/s]
#                    all        325       1304      0.937       0.96      0.933      0.503
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       45/49      2.04G    0.04011    0.02002          0         28        416: 100% 72/72 [00:10<00:00,  6.63it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 11/11 [00:03<00:00,  3.31it/s]
#                    all        325       1304      0.935       0.96       0.94      0.506
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       46/49      2.04G    0.03965    0.01938          0         10        416: 100% 72/72 [00:10<00:00,  6.82it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 11/11 [00:03<00:00,  3.61it/s]
#                    all        325       1304      0.939      0.962      0.943      0.512
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       47/49      2.04G    0.04002    0.01867          0         13        416: 100% 72/72 [00:11<00:00,  6.48it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 11/11 [00:02<00:00,  4.22it/s]
#                    all        325       1304      0.918      0.926      0.925      0.461
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       48/49      2.04G    0.04067    0.01931          0         28        416: 100% 72/72 [00:11<00:00,  6.48it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 11/11 [00:02<00:00,  4.16it/s]
#                    all        325       1304      0.933      0.966      0.938      0.515
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       49/49      2.04G    0.04049    0.01973          0         14        416: 100% 72/72 [00:11<00:00,  6.47it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 11/11 [00:02<00:00,  4.15it/s]
#                    all        325       1304      0.938      0.956       0.94      0.507
#
# 50 epochs completed in 0.206 hours.
# Optimizer stripped from runs/train/yolov5s_results/weights/last.pt, 14.8MB
# Optimizer stripped from runs/train/yolov5s_results/weights/best.pt, 14.8MB
#
# Validating runs/train/yolov5s_results/weights/best.pt...
# Fusing layers...
# custom_YOLOv5s summary: 182 layers, 7246518 parameters, 0 gradients
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 11/11 [00:07<00:00,  1.48it/s]
#                    all        325       1304      0.933      0.966      0.938      0.515
# Results saved to runs/train/yolov5s_results
# CPU times: user 10 s, sys: 1.01 s, total: 11 s
# Wall time: 13min 17s

# %% [markdown]
# # Evaluate Custom YOLOv5 Detector Performance

# %% [markdown]
# You can view the training graphs associated with a training job in the `/content/yolov5/runs/train/yolov5s_results/results.png` folder.
#
# Training losses and performance metrics are also saved to Tensorboard and also to a logfile defined above with the **--name** flag when we train. In our case, we named this `yolov5s_results`.
#
# Note from Glenn: Partially completed `results.txt` files can be plotted with `from utils.utils import plot_results; plot_results()`.

# %%
from utils.plots import plot_results  # plot results.txt as results.png
Image(filename='/content/yolov5/runs/train/yolov5s_results/results.png', width=1000)  # view results.png

# %% [markdown]
# ### Curious? Visualize Our Training Data with Labels
#
# After training starts, view `train*.jpg` images to see training images, labels and augmentation effects.
#
# Note a mosaic dataloader is used for training (shown below), a new dataloading concept developed by Glenn Jocher and first featured in [YOLOv4](https://arxiv.org/abs/2004.10934).

# %%
Image(filename='/content/yolov5/runs/train/yolov5s_results/val_batch0_labels.jpg', width=900)

# %%
# print out an augmented training example
print("GROUND TRUTH AUGMENTED TRAINING DATA:")
Image(filename='/content/yolov5/runs/train/yolov5s_results/train_batch0.jpg', width=900)
# Out:
# GROUND TRUTH AUGMENTED TRAINING DATA:

# %% [markdown]
# # Run Inference With Trained Weights
#
# Next, we can run inference with a pretrained checkpoint on all images in the `test/images` folder to understand how our model performs on our test set.

# %%
# trained weights are saved by default in our weights folder
# %ls runs/
# Out:
# train/

# %%
# %ls runs/train/yolov5s_results/weights
# Out:
# best.pt  last.pt

# %% [markdown]
# In the snippet below, replace `Cash-Counter-10` with the name of the folder in which your dataset is stored.

# %%
# %cd /content/yolov5/
# !python detect.py --weights runs/train/yolov5s_results/weights/best.pt --img 416 --conf 0.4 --source /content/yolov5/PalmerNotation-2/test/images
# Out:
# /content/yolov5
# detect: weights=['runs/train/yolov5s_results/weights/best.pt'], source=/content/yolov5/PalmerNotation-2/test/images, data=data/coco128.yaml, imgsz=[416, 416], conf_thres=0.4, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-295-gac6c4383 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# custom_YOLOv5s summary: 182 layers, 7246518 parameters, 0 gradients
# image 1/163 /content/yolov5/PalmerNotation-2/test/images/ID-1-20-files-merged-_page-0004_jpg.rf.dc8c930f479326c7f6f587d631219c1d.jpg: 416x416 6 palmers, 7.7ms
# image 2/163 /content/yolov5/PalmerNotation-2/test/images/SOORYA-DHR03202024_0041_jpg.rf.1ac4f085fbb9371df67e72118faa68e7.jpg: 416x416 3 palmers, 7.8ms
# image 3/163 /content/yolov5/PalmerNotation-2/test/images/SOORYA-DHR03202024_0044_jpg.rf.7d7b02f3422f31abb70c2f70db416f61.jpg: 416x416 (no detections), 7.7ms
# image 4/163 /content/yolov5/PalmerNotation-2/test/images/SOORYA-DHR03212024_0024_jpg.rf.bc8b4aedaaece17a70b609be9b8e6c8b.jpg: 416x416 2 palmers, 7.7ms
# image 5/163 /content/yolov5/PalmerNotation-2/test/images/SOORYA-DHR03212024_0033_jpg.rf.832e13a2afc24f0ba81e474d82233b1b.jpg: 416x416 6 palmers, 7.7ms
# image 6/163 /content/yolov5/PalmerNotation-2/test/images/SOORYA-DHR03212024_0043_jpg.rf.3ef387d963c9e29f87167f6b6f195c07.jpg: 416x416 4 palmers, 7.7ms
# image 7/163 /content/yolov5/PalmerNotation-2/test/images/SOORYA-DHR03212024_0058_jpg.rf.4b99946d3f45447100a401be97b2465f.jpg: 416x416 6 palmers, 7.7ms
# image 8/163 /content/yolov5/PalmerNotation-2/test/images/SOORYA-DHR03212024_0061_jpg.rf.b22b6cf2d9d4f4eb3e5c2e5fbdad060d.jpg: 416x416 1 palmer, 7.7ms
# image 9/163 /content/yolov5/PalmerNotation-2/test/images/SOORYA-DHR03212024_0065_jpg.rf.09b1624dc04f499dc5d9e772e9a5559e.jpg: 416x416 2 palmers, 7.6ms
# image 10/163 /content/yolov5/PalmerNotation-2/test/images/augmented_103_jpg.rf.004c5181c17c0191bcc75bd4cb8c78e2.jpg: 416x416 7 palmers, 7.7ms
# image 11/163 /content/yolov5/PalmerNotation-2/test/images/augmented_105_jpg.rf.f85f96bd87d6f4a2e6be7c713ac1d6bb.jpg: 416x416 2 palmers, 10.5ms
# image 12/163 /content/yolov5/PalmerNotation-2/test/images/augmented_106_jpg.rf.c16ce75e33607ef92b1c06005cfeeb4b.jpg: 416x416 3 palmers, 7.7ms
# image 13/163 /content/yolov5/PalmerNotation-2/test/images/augmented_107_jpg.rf.54d31c1a93f7be432d995d0c251e3f41.jpg: 416x416 3 palmers, 7.7ms
# image 14/163 /content/yolov5/PalmerNotation-2/test/images/augmented_107_jpg.rf.5dbc2ce7a02970cb6a456feef124d127.jpg: 416x416 3 palmers, 7.6ms
# image 15/163 /content/yolov5/PalmerNotation-2/test/images/augmented_107_jpg.rf.e68b38b75d92abf72ba8c34fd4bcd605.jpg: 416x416 2 palmers, 7.7ms
# image 16/163 /content/yolov5/PalmerNotation-2/test/images/augmented_108_jpg.rf.69c3d7ebf3b5e8b5831d67ad343d6a50.jpg: 416x416 3 palmers, 7.6ms
# image 17/163 /content/yolov5/PalmerNotation-2/test/images/augmented_108_jpg.rf.8835b6159fefa2a8ebcaf08b0a2b54b1.jpg: 416x416 2 palmers, 7.6ms
# image 18/163 /content/yolov5/PalmerNotation-2/test/images/augmented_108_jpg.rf.edc1f43454b8b81bdbbe6ebbd3bb65c5.jpg: 416x416 2 palmers, 7.6ms
# image 19/163 /content/yolov5/PalmerNotation-2/test/images/augmented_110_jpg.rf.0a35ab19971291378bbf3f7a14907591.jpg: 416x416 2 palmers, 7.7ms
# image 20/163 /content/yolov5/PalmerNotation-2/test/images/augmented_110_jpg.rf.a87b6d1346cb636e718548e533bb34fa.jpg: 416x416 2 palmers, 7.7ms
# image 21/163 /content/yolov5/PalmerNotation-2/test/images/augmented_111_jpg.rf.58de56b6a7be1b7e92e7faa839885ee4.jpg: 416x416 6 palmers, 7.7ms
# image 22/163 /content/yolov5/PalmerNotation-2/test/images/augmented_111_jpg.rf.f6706b1af51a515992c5185a41e739b7.jpg: 416x416 5 palmers, 7.7ms
# image 23/163 /content/yolov5/PalmerNotation-2/test/images/augmented_112_jpg.rf.951d37d05adbeb744ff15afc7b4e39d1.jpg: 416x416 6 palmers, 7.6ms
# image 24/163 /content/yolov5/PalmerNotation-2/test/images/augmented_113_jpg.rf.ccf74ad758579297f5e0240a2c19fe0b.jpg: 416x416 6 palmers, 11.1ms
# image 25/163 /content/yolov5/PalmerNotation-2/test/images/augmented_117_jpg.rf.cd0407fe097259346c438ed3f2017f0d.jpg: 416x416 4 palmers, 7.7ms
# image 26/163 /content/yolov5/PalmerNotation-2/test/images/augmented_119_jpg.rf.ecd8a6195e25d201ae33db7a725ac764.jpg: 416x416 4 palmers, 7.7ms
# image 27/163 /content/yolov5/PalmerNotation-2/test/images/augmented_11_jpg.rf.d65cfc1f133c9ee7de41f0e2bd46488d.jpg: 416x416 7 palmers, 7.7ms
# image 28/163 /content/yolov5/PalmerNotation-2/test/images/augmented_120_jpg.rf.dff439ba985bccbd7d35abbaeaa4192a.jpg: 416x416 7 palmers, 7.6ms
# image 29/163 /content/yolov5/PalmerNotation-2/test/images/augmented_121_jpg.rf.1dac204a29a3a17ff765a30b4f37d078.jpg: 416x416 4 palmers, 12.2ms
# image 30/163 /content/yolov5/PalmerNotation-2/test/images/augmented_121_jpg.rf.58fcd8d7c21ea351a3e65b2587601d83.jpg: 416x416 4 palmers, 7.7ms
# image 31/163 /content/yolov5/PalmerNotation-2/test/images/augmented_122_jpg.rf.0b5bc1d5a80b0cf14208bbb0312f4304.jpg: 416x416 6 palmers, 7.7ms
# image 32/163 /content/yolov5/PalmerNotation-2/test/images/augmented_122_jpg.rf.73ca13bce4e412d2309cde1f5f5c57f6.jpg: 416x416 7 palmers, 7.7ms
# image 33/163 /content/yolov5/PalmerNotation-2/test/images/augmented_124_jpg.rf.7fd6e6ee65d2d354d9e06a0eb47fcd4d.jpg: 416x416 10 palmers, 7.7ms
# image 34/163 /content/yolov5/PalmerNotation-2/test/images/augmented_124_jpg.rf.e9e3b64e41f9aa72b4da5b36e3f452c8.jpg: 416x416 12 palmers, 7.7ms
# image 35/163 /content/yolov5/PalmerNotation-2/test/images/augmented_126_jpg.rf.5eb510386cd8aa501388a2e8fdead66c.jpg: 416x416 9 palmers, 7.6ms
# image 36/163 /content/yolov5/PalmerNotation-2/test/images/augmented_126_jpg.rf.9ade55fd81e430a1cbdcf89c161ce3b8.jpg: 416x416 8 palmers, 7.7ms
# image 37/163 /content/yolov5/PalmerNotation-2/test/images/augmented_126_jpg.rf.9eb438fd5e4afb023d9bdcae9ccb8e1e.jpg: 416x416 5 palmers, 7.7ms
# image 38/163 /content/yolov5/PalmerNotation-2/test/images/augmented_126_jpg.rf.e17d42ed887f094767e7f97bfedf9274.jpg: 416x416 5 palmers, 7.7ms
# image 39/163 /content/yolov5/PalmerNotation-2/test/images/augmented_128_jpg.rf.85f832c02ac491bc8b3d89013ee57784.jpg: 416x416 8 palmers, 7.7ms
# image 40/163 /content/yolov5/PalmerNotation-2/test/images/augmented_128_jpg.rf.f584d382eec05a03848edb8f6d969ea8.jpg: 416x416 8 palmers, 7.8ms
# image 41/163 /content/yolov5/PalmerNotation-2/test/images/augmented_130_jpg.rf.966175cc8f06ef25e6282e7ad0abceeb.jpg: 416x416 2 palmers, 7.7ms
# image 42/163 /content/yolov5/PalmerNotation-2/test/images/augmented_131_jpg.rf.7bfab28048e94ae1f7ecc683517d31fb.jpg: 416x416 6 palmers, 7.7ms
# image 43/163 /content/yolov5/PalmerNotation-2/test/images/augmented_131_jpg.rf.de50995dd774ed8d18408e827fc050ba.jpg: 416x416 2 palmers, 7.7ms
# image 44/163 /content/yolov5/PalmerNotation-2/test/images/augmented_132_jpg.rf.278d27003ccf61c32155874c436860b7.jpg: 416x416 2 palmers, 7.7ms
# image 45/163 /content/yolov5/PalmerNotation-2/test/images/augmented_134_jpg.rf.a55e1830adcb7f71db24ed7ef527782b.jpg: 416x416 2 palmers, 7.7ms
# image 46/163 /content/yolov5/PalmerNotation-2/test/images/augmented_134_jpg.rf.bb09727b437c24f6d37177ad74388d94.jpg: 416x416 2 palmers, 7.7ms
# image 47/163 /content/yolov5/PalmerNotation-2/test/images/augmented_138_jpg.rf.5077fe16a0c184c03780fe05d8c8ddd2.jpg: 416x416 1 palmer, 10.1ms
# image 48/163 /content/yolov5/PalmerNotation-2/test/images/augmented_138_jpg.rf.d5a66e4bcf4b7c526e9b4fcad3276110.jpg: 416x416 4 palmers, 7.7ms
# image 49/163 /content/yolov5/PalmerNotation-2/test/images/augmented_140_jpg.rf.aef8dd267ceca5d0fc4b0975ab18a206.jpg: 416x416 1 palmer, 7.6ms
# image 50/163 /content/yolov5/PalmerNotation-2/test/images/augmented_141_jpg.rf.fe0bb9e981783994e255500c90f52276.jpg: 416x416 3 palmers, 7.7ms
# image 51/163 /content/yolov5/PalmerNotation-2/test/images/augmented_142_jpg.rf.fd867903a16582905e55092a2388235a.jpg: 416x416 3 palmers, 7.7ms
# image 52/163 /content/yolov5/PalmerNotation-2/test/images/augmented_143_jpg.rf.0039f80fa39914ac8068ec643e33b399.jpg: 416x416 1 palmer, 7.7ms
# image 53/163 /content/yolov5/PalmerNotation-2/test/images/augmented_143_jpg.rf.abae16e726d8f00df81690b25192f1fa.jpg: 416x416 3 palmers, 7.6ms
# image 54/163 /content/yolov5/PalmerNotation-2/test/images/augmented_149_jpg.rf.99d4effcb472c6274aa3edb36894f87b.jpg: 416x416 2 palmers, 8.4ms
# image 55/163 /content/yolov5/PalmerNotation-2/test/images/augmented_14_jpg.rf.019a70b8a449d3270cb9033cbdd2ecc8.jpg: 416x416 7 palmers, 7.7ms
# image 56/163 /content/yolov5/PalmerNotation-2/test/images/augmented_14_jpg.rf.2c0547f6d9376bc007d2ab9feab80ddc.jpg: 416x416 7 palmers, 7.6ms
# image 57/163 /content/yolov5/PalmerNotation-2/test/images/augmented_14_jpg.rf.ce03fa2c0ea7a317c7b3f0748267933c.jpg: 416x416 7 palmers, 7.6ms
# image 58/163 /content/yolov5/PalmerNotation-2/test/images/augmented_151_jpg.rf.2978443410da921cb4c0691c143fa994.jpg: 416x416 4 palmers, 7.7ms
# image 59/163 /content/yolov5/PalmerNotation-2/test/images/augmented_151_jpg.rf.b1abc7c1de54cfce608b761cba7edc66.jpg: 416x416 4 palmers, 7.7ms
# image 60/163 /content/yolov5/PalmerNotation-2/test/images/augmented_152_jpg.rf.3d1f52a4ff11edbf5c850c6eedbc5ce7.jpg: 416x416 5 palmers, 7.7ms
# image 61/163 /content/yolov5/PalmerNotation-2/test/images/augmented_152_jpg.rf.eade4f9d959befd98b77bacb60c0abd1.jpg: 416x416 3 palmers, 7.7ms
# image 62/163 /content/yolov5/PalmerNotation-2/test/images/augmented_153_jpg.rf.28894f93ea70488fd56a3ad87f6d175a.jpg: 416x416 2 palmers, 7.7ms
# image 63/163 /content/yolov5/PalmerNotation-2/test/images/augmented_154_jpg.rf.74f3e8f522f174ca4f8bd75be81378b2.jpg: 416x416 2 palmers, 7.7ms
# image 64/163 /content/yolov5/PalmerNotation-2/test/images/augmented_15_jpg.rf.1db02ecb6026c25a5b35e2b7721467b4.jpg: 416x416 2 palmers, 7.6ms
# image 65/163 /content/yolov5/PalmerNotation-2/test/images/augmented_162_jpg.rf.6fc8d28259a229c280b74ceffeb52934.jpg: 416x416 1 palmer, 7.6ms
# image 66/163 /content/yolov5/PalmerNotation-2/test/images/augmented_171_jpg.rf.159f5c8ea0e600d387352f2ab649eacc.jpg: 416x416 1 palmer, 7.6ms
# image 67/163 /content/yolov5/PalmerNotation-2/test/images/augmented_171_jpg.rf.9795e9cc2f586f6f2f8f0126f7edd706.jpg: 416x416 1 palmer, 7.7ms
# image 68/163 /content/yolov5/PalmerNotation-2/test/images/augmented_172_jpg.rf.5af715bfc2dc6aa88ca459956ce57445.jpg: 416x416 1 palmer, 7.7ms
# image 69/163 /content/yolov5/PalmerNotation-2/test/images/augmented_172_jpg.rf.6e887b45501c697cf576811f04fa5767.jpg: 416x416 1 palmer, 7.7ms
# image 70/163 /content/yolov5/PalmerNotation-2/test/images/augmented_173_jpg.rf.0452dda72344eec2c518a21ce389276a.jpg: 416x416 1 palmer, 7.7ms
# image 71/163 /content/yolov5/PalmerNotation-2/test/images/augmented_173_jpg.rf.49f312f18744efe44af6989491439ea6.jpg: 416x416 1 palmer, 12.7ms
# image 72/163 /content/yolov5/PalmerNotation-2/test/images/augmented_175_jpg.rf.c82e6ce467361fa76a5cf443cb7d5548.jpg: 416x416 3 palmers, 7.7ms
# image 73/163 /content/yolov5/PalmerNotation-2/test/images/augmented_182_jpg.rf.3ce389031e655945d76a96db276bbe00.jpg: 416x416 3 palmers, 7.7ms
# image 74/163 /content/yolov5/PalmerNotation-2/test/images/augmented_183_jpg.rf.98f1e20966adedce27fab892cb5413e6.jpg: 416x416 2 palmers, 7.7ms
# image 75/163 /content/yolov5/PalmerNotation-2/test/images/augmented_184_jpg.rf.1e3bee2c234c1cc5bbdaa9bf0ae357d3.jpg: 416x416 2 palmers, 7.7ms
# image 76/163 /content/yolov5/PalmerNotation-2/test/images/augmented_185_jpg.rf.20f39900f6dd8d950329496e88c6159a.jpg: 416x416 2 palmers, 11.1ms
# image 77/163 /content/yolov5/PalmerNotation-2/test/images/augmented_187_jpg.rf.c93a8e384854c300ab603ac408687f6d.jpg: 416x416 4 palmers, 8.0ms
# image 78/163 /content/yolov5/PalmerNotation-2/test/images/augmented_194_jpg.rf.9d74e73b00dc0e5168903da3b8dc696f.jpg: 416x416 2 palmers, 7.7ms
# image 79/163 /content/yolov5/PalmerNotation-2/test/images/augmented_197_jpg.rf.488bea17d089f85dd295ec25b7b3a7fa.jpg: 416x416 4 palmers, 7.7ms
# image 80/163 /content/yolov5/PalmerNotation-2/test/images/augmented_197_jpg.rf.7b3f49d13acffe74f904d17cd8310eb2.jpg: 416x416 4 palmers, 9.5ms
# image 81/163 /content/yolov5/PalmerNotation-2/test/images/augmented_19_jpg.rf.59cb1346fb705d069f509b65c476daed.jpg: 416x416 2 palmers, 7.8ms
# image 82/163 /content/yolov5/PalmerNotation-2/test/images/augmented_201_jpg.rf.7db2014e984c7774ddde456ba7b07883.jpg: 416x416 7 palmers, 7.7ms
# image 83/163 /content/yolov5/PalmerNotation-2/test/images/augmented_202_jpg.rf.ef776c5a3c62f1c40d2a1afa8badc439.jpg: 416x416 7 palmers, 8.6ms
# image 84/163 /content/yolov5/PalmerNotation-2/test/images/augmented_202_jpg.rf.f4c622c0087350110f438601d1b47937.jpg: 416x416 7 palmers, 7.7ms
# image 85/163 /content/yolov5/PalmerNotation-2/test/images/augmented_203_jpg.rf.904116a0c074399aba4c516421653b83.jpg: 416x416 7 palmers, 7.7ms
# image 86/163 /content/yolov5/PalmerNotation-2/test/images/augmented_205_jpg.rf.292772e4afc798fb122989adcb65aac4.jpg: 416x416 3 palmers, 7.7ms
# image 87/163 /content/yolov5/PalmerNotation-2/test/images/augmented_206_jpg.rf.149b37973e8768782dc320ebb5fafe16.jpg: 416x416 3 palmers, 7.7ms
# image 88/163 /content/yolov5/PalmerNotation-2/test/images/augmented_208_jpg.rf.c46b1289255b0279e09091cd63ca2843.jpg: 416x416 4 palmers, 7.7ms
# image 89/163 /content/yolov5/PalmerNotation-2/test/images/augmented_209_jpg.rf.da6231712c8381ad77da7b8c45fe123e.jpg: 416x416 4 palmers, 7.7ms
# image 90/163 /content/yolov5/PalmerNotation-2/test/images/augmented_21_jpg.rf.7bb21dc3bb29aecb5b9ee71e5a17be1e.jpg: 416x416 2 palmers, 7.7ms
# image 91/163 /content/yolov5/PalmerNotation-2/test/images/augmented_22_jpg.rf.144efba2fcbc080b457cf821f4a5e376.jpg: 416x416 2 palmers, 7.7ms
# image 92/163 /content/yolov5/PalmerNotation-2/test/images/augmented_22_jpg.rf.e07003ccefff1d3d11c97d15a80b48e9.jpg: 416x416 4 palmers, 7.7ms
# image 93/163 /content/yolov5/PalmerNotation-2/test/images/augmented_23_jpg.rf.16aa645a0c23b45d634e17f718a2821c.jpg: 416x416 4 palmers, 7.8ms
# image 94/163 /content/yolov5/PalmerNotation-2/test/images/augmented_23_jpg.rf.67abf0bee5c1513b1ff20b8032f514ca.jpg: 416x416 4 palmers, 7.7ms
# image 95/163 /content/yolov5/PalmerNotation-2/test/images/augmented_27_jpg.rf.269fc069d088a35d6176acad93df6d76.jpg: 416x416 3 palmers, 14.7ms
# image 96/163 /content/yolov5/PalmerNotation-2/test/images/augmented_27_jpg.rf.781208947868b54ebec13ba221b3b93f.jpg: 416x416 9 palmers, 12.3ms
# image 97/163 /content/yolov5/PalmerNotation-2/test/images/augmented_28_jpg.rf.24591fe2fbc7ec4324be318dfd3b2bff.jpg: 416x416 3 palmers, 12.7ms
# image 98/163 /content/yolov5/PalmerNotation-2/test/images/augmented_28_jpg.rf.367a6ab3e67d1d10be1b75359e9b0225.jpg: 416x416 3 palmers, 9.8ms
# image 99/163 /content/yolov5/PalmerNotation-2/test/images/augmented_29_jpg.rf.1b46f42063e36dfb23473f66274a6621.jpg: 416x416 9 palmers, 10.1ms
# image 100/163 /content/yolov5/PalmerNotation-2/test/images/augmented_2_jpg.rf.54f6cb5a97e06f0f280b0e54022f9f64.jpg: 416x416 3 palmers, 10.7ms
# image 101/163 /content/yolov5/PalmerNotation-2/test/images/augmented_2_jpg.rf.a6cabbfc8da1d5b28ae3b7e1c6935661.jpg: 416x416 9 palmers, 12.3ms
# image 102/163 /content/yolov5/PalmerNotation-2/test/images/augmented_30_jpg.rf.a88e1e33a2bc2eecb654c88649448120.jpg: 416x416 2 palmers, 9.5ms
# image 103/163 /content/yolov5/PalmerNotation-2/test/images/augmented_33_jpg.rf.8abe4f2ec20a7d5e2752dfc9f4fc52ab.jpg: 416x416 5 palmers, 10.2ms
# image 104/163 /content/yolov5/PalmerNotation-2/test/images/augmented_34_jpg.rf.ac9011119db3a08843ff8fd1e90b24ac.jpg: 416x416 2 palmers, 9.8ms
# image 105/163 /content/yolov5/PalmerNotation-2/test/images/augmented_36_jpg.rf.c311695c9e331eefe02ff53ed56d8a4f.jpg: 416x416 7 palmers, 9.7ms
# image 106/163 /content/yolov5/PalmerNotation-2/test/images/augmented_38_jpg.rf.50d0b7572fceef192c94cecc8e22290f.jpg: 416x416 9 palmers, 14.4ms
# image 107/163 /content/yolov5/PalmerNotation-2/test/images/augmented_40_jpg.rf.aabe3346c0e328ddaf2b52a697caa343.jpg: 416x416 9 palmers, 9.5ms
# image 108/163 /content/yolov5/PalmerNotation-2/test/images/augmented_41_jpg.rf.26e7dd4b2c4c197443e1e13f094ff109.jpg: 416x416 9 palmers, 9.3ms
# image 109/163 /content/yolov5/PalmerNotation-2/test/images/augmented_42_jpg.rf.1a6bdabc03178451510330de33802a56.jpg: 416x416 5 palmers, 9.5ms
# image 110/163 /content/yolov5/PalmerNotation-2/test/images/augmented_42_jpg.rf.5d824721f4073aa46b7387da5380a1c4.jpg: 416x416 2 palmers, 9.2ms
# image 111/163 /content/yolov5/PalmerNotation-2/test/images/augmented_43_jpg.rf.60339a3a92dca710e3ac47d7aa4d5bc4.jpg: 416x416 2 palmers, 9.3ms
# image 112/163 /content/yolov5/PalmerNotation-2/test/images/augmented_43_jpg.rf.ed8b8623fcff54746f272dc90c8681f5.jpg: 416x416 5 palmers, 9.6ms
# image 113/163 /content/yolov5/PalmerNotation-2/test/images/augmented_45_jpg.rf.20a1e0456fecfa7756aacb6e11fe9bb3.jpg: 416x416 2 palmers, 9.3ms
# image 114/163 /content/yolov5/PalmerNotation-2/test/images/augmented_45_jpg.rf.933851cb1b1e516e2a8137d112ba0cfc.jpg: 416x416 2 palmers, 11.3ms
# image 115/163 /content/yolov5/PalmerNotation-2/test/images/augmented_46_jpg.rf.8e5123896c03de53ecf0fd1ee7dbffb7.jpg: 416x416 2 palmers, 9.9ms
# image 116/163 /content/yolov5/PalmerNotation-2/test/images/augmented_46_jpg.rf.e893c218d5cf3c89f018d46a6c6836f1.jpg: 416x416 2 palmers, 9.9ms
# image 117/163 /content/yolov5/PalmerNotation-2/test/images/augmented_47_jpg.rf.3b232e524332e7fdb38385a6419d4e1b.jpg: 416x416 2 palmers, 9.7ms
# image 118/163 /content/yolov5/PalmerNotation-2/test/images/augmented_47_jpg.rf.6304ba08db2de213b5eb1cf31b58b997.jpg: 416x416 2 palmers, 8.9ms
# image 119/163 /content/yolov5/PalmerNotation-2/test/images/augmented_50_jpg.rf.a7350aac326c8f713a082774d7419cce.jpg: 416x416 3 palmers, 9.8ms
# image 120/163 /content/yolov5/PalmerNotation-2/test/images/augmented_50_jpg.rf.b8754e7906ab56ab41e5b6100e84e1d8.jpg: 416x416 3 palmers, 9.4ms
# image 121/163 /content/yolov5/PalmerNotation-2/test/images/augmented_52_jpg.rf.2a51ddef3cf0eb985405008ff4abdb43.jpg: 416x416 6 palmers, 9.3ms
# image 122/163 /content/yolov5/PalmerNotation-2/test/images/augmented_53_jpg.rf.503b8b7610f46e1ec5a166f456efa85f.jpg: 416x416 5 palmers, 8.9ms
# image 123/163 /content/yolov5/PalmerNotation-2/test/images/augmented_54_jpg.rf.3135f88fcdfce6f918afe26714fdd39a.jpg: 416x416 5 palmers, 10.4ms
# image 124/163 /content/yolov5/PalmerNotation-2/test/images/augmented_54_jpg.rf.8cfff60517d08d56793a1b4d88f0a361.jpg: 416x416 5 palmers, 9.1ms
# image 125/163 /content/yolov5/PalmerNotation-2/test/images/augmented_59_jpg.rf.5546cb494d3c724493de927a514cc2e5.jpg: 416x416 1 palmer, 9.5ms
# image 126/163 /content/yolov5/PalmerNotation-2/test/images/augmented_60_jpg.rf.10076484e31599a021384e50ea03275b.jpg: 416x416 3 palmers, 10.5ms
# image 127/163 /content/yolov5/PalmerNotation-2/test/images/augmented_60_jpg.rf.6a9eff5b016d83acbbcf2bada09297f4.jpg: 416x416 4 palmers, 9.4ms
# image 128/163 /content/yolov5/PalmerNotation-2/test/images/augmented_60_jpg.rf.98a9cd13c40b1659a9a999164265ddad.jpg: 416x416 5 palmers, 9.2ms
# image 129/163 /content/yolov5/PalmerNotation-2/test/images/augmented_61_jpg.rf.ba9671b2f60d16bb7fad55486b9f5fe2.jpg: 416x416 5 palmers, 13.8ms
# image 130/163 /content/yolov5/PalmerNotation-2/test/images/augmented_61_jpg.rf.c0385f3f8c57b66222ee65486db2c439.jpg: 416x416 4 palmers, 10.8ms
# image 131/163 /content/yolov5/PalmerNotation-2/test/images/augmented_62_jpg.rf.9ecb67ea962a99302604a03b0498c113.jpg: 416x416 5 palmers, 12.7ms
# image 132/163 /content/yolov5/PalmerNotation-2/test/images/augmented_63_jpg.rf.0fdc44ce342e4e92a8377dca3750a276.jpg: 416x416 3 palmers, 9.5ms
# image 133/163 /content/yolov5/PalmerNotation-2/test/images/augmented_64_jpg.rf.98f2b8f65e1a686cb9243d22a0001680.jpg: 416x416 4 palmers, 13.3ms
# image 134/163 /content/yolov5/PalmerNotation-2/test/images/augmented_65_jpg.rf.5ec02d31f6fc475ad92fbe1d95cf9c85.jpg: 416x416 3 palmers, 17.3ms
# image 135/163 /content/yolov5/PalmerNotation-2/test/images/augmented_66_jpg.rf.b0b7bf1ebef612ab9fae38e3a8a6424b.jpg: 416x416 3 palmers, 11.9ms
# image 136/163 /content/yolov5/PalmerNotation-2/test/images/augmented_68_jpg.rf.12e6d8ceb274ff9e6794e167ac168f5c.jpg: 416x416 2 palmers, 14.0ms
# image 137/163 /content/yolov5/PalmerNotation-2/test/images/augmented_6_jpg.rf.753702bbc81083156b5f0924ad64e013.jpg: 416x416 13 palmers, 9.3ms
# image 138/163 /content/yolov5/PalmerNotation-2/test/images/augmented_6_jpg.rf.9595b513818f8b3c5c42821d244643ae.jpg: 416x416 13 palmers, 11.7ms
# image 139/163 /content/yolov5/PalmerNotation-2/test/images/augmented_71_jpg.rf.2d73a351d039b45224a701041beae3ff.jpg: 416x416 8 palmers, 12.8ms
# image 140/163 /content/yolov5/PalmerNotation-2/test/images/augmented_73_jpg.rf.637b72991733153b509038bf61cad083.jpg: 416x416 2 palmers, 14.9ms
# image 141/163 /content/yolov5/PalmerNotation-2/test/images/augmented_73_jpg.rf.9208a4aa1d447a04c589858dce548792.jpg: 416x416 2 palmers, 12.8ms
# image 142/163 /content/yolov5/PalmerNotation-2/test/images/augmented_74_jpg.rf.73ec425e4553b617a2df5409bc792ba8.jpg: 416x416 2 palmers, 9.5ms
# image 143/163 /content/yolov5/PalmerNotation-2/test/images/augmented_82_jpg.rf.e10c1a1f69378b87af87ae08883b540a.jpg: 416x416 (no detections), 11.9ms
# image 144/163 /content/yolov5/PalmerNotation-2/test/images/augmented_83_jpg.rf.73c3cf9e2e69e936d07f443ea1a75a09.jpg: 416x416 2 palmers, 13.8ms
# image 145/163 /content/yolov5/PalmerNotation-2/test/images/augmented_83_jpg.rf.cf002e139b867bcb49af96683132f4d6.jpg: 416x416 2 palmers, 12.9ms
# image 146/163 /content/yolov5/PalmerNotation-2/test/images/augmented_84_jpg.rf.ebcdb71a573ca58223dd15986fdbd604.jpg: 416x416 4 palmers, 12.9ms
# image 147/163 /content/yolov5/PalmerNotation-2/test/images/augmented_85_jpg.rf.274dc32ce971a8bb7caf629024e54f9d.jpg: 416x416 4 palmers, 14.1ms
# image 148/163 /content/yolov5/PalmerNotation-2/test/images/augmented_8_jpg.rf.627027fc0b943883a99bd4f8bd022761.jpg: 416x416 13 palmers, 13.2ms
# image 149/163 /content/yolov5/PalmerNotation-2/test/images/augmented_8_jpg.rf.97fa6f001a6785a167ade8a1097dd7c1.jpg: 416x416 13 palmers, 13.3ms
# image 150/163 /content/yolov5/PalmerNotation-2/test/images/augmented_8_jpg.rf.bbb16618076ca4939abdae60cbc1b44c.jpg: 416x416 5 palmers, 12.5ms
# image 151/163 /content/yolov5/PalmerNotation-2/test/images/augmented_90_jpg.rf.92898cf21550edcc01789568b896082f.jpg: 416x416 2 palmers, 13.3ms
# image 152/163 /content/yolov5/PalmerNotation-2/test/images/augmented_90_jpg.rf.c385479baaa57094e6ceb9dc3e1d4227.jpg: 416x416 8 palmers, 12.6ms
# image 153/163 /content/yolov5/PalmerNotation-2/test/images/augmented_90_jpg.rf.f5f3e8d4a27cde3c6adf25919b7c838f.jpg: 416x416 2 palmers, 7.7ms
# image 154/163 /content/yolov5/PalmerNotation-2/test/images/augmented_91_jpg.rf.212e3cfd8070b60b1a21a9bbd5f08e4b.jpg: 416x416 9 palmers, 7.6ms
# image 155/163 /content/yolov5/PalmerNotation-2/test/images/augmented_91_jpg.rf.3c076d432b5a4a0102ec8edf60b7a635.jpg: 416x416 2 palmers, 7.7ms
# image 156/163 /content/yolov5/PalmerNotation-2/test/images/augmented_93_jpg.rf.6f11eb564db0dc87d8c05514812d2fdd.jpg: 416x416 4 palmers, 7.9ms
# image 157/163 /content/yolov5/PalmerNotation-2/test/images/augmented_93_jpg.rf.d23cfe344dd2520040127543f873bf51.jpg: 416x416 4 palmers, 7.7ms
# image 158/163 /content/yolov5/PalmerNotation-2/test/images/augmented_94_jpg.rf.5ebcec8ff3e63f946c3d7abb1a4965ac.jpg: 416x416 4 palmers, 7.7ms
# image 159/163 /content/yolov5/PalmerNotation-2/test/images/augmented_95_jpg.rf.06f6ad7eb303ab2e215a6c77e9a465d4.jpg: 416x416 2 palmers, 7.7ms
# image 160/163 /content/yolov5/PalmerNotation-2/test/images/augmented_96_jpg.rf.32db97a7eb537e25430494927b8e5dee.jpg: 416x416 4 palmers, 7.6ms
# image 161/163 /content/yolov5/PalmerNotation-2/test/images/augmented_97_jpg.rf.c3db79854d92480d56b929ca281dcd7b.jpg: 416x416 4 palmers, 7.7ms
# image 162/163 /content/yolov5/PalmerNotation-2/test/images/augmented_9_jpg.rf.ea4d12b0ac910e2699e54fe32c88906c.jpg: 416x416 5 palmers, 7.6ms
# image 163/163 /content/yolov5/PalmerNotation-2/test/images/img60_jpg.rf.a89196c444da5e386cac1b3e7ae81445.jpg: 416x416 5 palmers, 7.7ms
# Speed: 0.3ms pre-process, 9.1ms inference, 4.4ms NMS per image at shape (1, 3, 416, 416)
# Results saved to runs/detect/exp2

# %%
import glob
from IPython.display import Image, display

for imageName in glob.glob('/content/yolov5/runs/detect/exp/*.jpg')[:10]: #assuming JPG
    display(Image(filename=imageName))
